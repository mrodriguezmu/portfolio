# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
pd.set_option('display.max_colwidth', 500)
import time
import requests
import random

# %%
rate = [i/10 for i in range(10)]

# %%
fechas=[]
for nit in datos['hola']:
  page = requests.get('https://www.einforma.co/servlet/app/portal/ENTP/prod/LISTA_EMPRESAS/razonsocial/'+str(nit))
  soup = bs(page.content)
  lista=[]
  for word in soup.find_all('td'):
    lista.append(word.get_text())
  try:
    indice=lista.index('Fecha Constitución:')
    fechas.append(lista[indice+1])
  except:
    fechas.append('')
  time.sleep(random.choice(rate))

# %%
fechas
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
datos['fecha']=fechas

# %%
datos.to_excel(r'fechas.xlsx', index=False)
