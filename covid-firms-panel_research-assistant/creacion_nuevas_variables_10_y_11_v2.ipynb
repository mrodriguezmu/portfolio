# %%
# Importamos las distintas librerias que vamos a utilizar:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import stats
import scipy
import statsmodels.api as sm
import statsmodels.formula.api as smf
import plotly
# %matplotlib inline
from sklearn.metrics import r2_score
import statistics

# %%
datos = pd.read_excel('Panel Completo superintendencia.xlsx')
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   NIT                               850 non-null    int64
#  1   Clasificación Profitability 2017  850 non-null    int64
#  2   Clasificación Growth 2017         850 non-null    int64
#  3   Clasificación Profitability 2018  850 non-null    int64
#  4   Clasificación Growth 2018         850 non-null    int64
#  5   Clasificación Profitability 2019  850 non-null    int64
#  6   Clasificación Growth 2019         850 non-null    int64
#  7   Clasificación Profitability 2020  850 non-null    int64
#  8   Clasificación Growth 2020         850 non-null    int64
#  9   Clasificación Profitability 2021  850 non-null    int64
#  10  Clasificación Growth 2021         850 non-null    int64
#  11  Performance Group 2017            850 non-null    object
# ...

# %%
# estadistica descriptiva

# rentabilidad para todo el periodo
datos['Profitability (Return on assets (%))'].describe()
# Out:
# count    4250.000000
# mean        9.682986
# std        11.373059
# min      -113.185399
# 25%         3.796426
# 50%         8.667722
# 75%        14.519722
# max        94.537016
# Name: Profitability (Return on assets (%)), dtype: float64

# %%
# crecimiento para todo el periodo
datos['Growth (%)'].describe()
# Out:
# count     4250.000000
# mean        14.867410
# std        257.595457
# min        -96.640894
# 25%         -6.467075
# 50%          5.677520
# 75%         20.874075
# max      15352.395800
# Name: Growth (%), dtype: float64

# %%
np.quantile(datos['Growth (%)'], [0,0.25,0.5,0.75,1])
# Out:
# array([-9.66408943e+01, -2.27132921e+01, -4.39796890e+00,  1.06679224e+01,
#         6.08272524e+03])

# %%
# cuartil para profitability 2017
cuartil = []
for i in datos['Profitability (Return on assets (%))']:
  if i <= 4.36491524:
    cuartil.append(1)
  elif 4.36491524 < i <= 8.68302877:
    cuartil.append(2)
  elif 8.68302877 < i <= 14.19913553:
    cuartil.append(3)
  elif i >14.19913553:
    cuartil.append(4)

# %%
# cuartil para growth 2017
cuartil = []
for i in datos['Growth (%)']:
  if i <= -8.92508225:
    cuartil.append(1)
  elif -8.92508225 < i <= 1.31534019:
    cuartil.append(2)
  elif 1.31534019 < i <= 11.13343796:
    cuartil.append(3)
  elif i >11.13343796:
    cuartil.append(4)

# %%
# cuartil para profitability 2018
cuartil1 = []
for i in datos['Profitability (Return on assets (%))']:
  if i <= 3.57186145:
    cuartil1.append(1)
  elif 3.57186145 < i <= 8.26705137:
    cuartil1.append(2)
  elif 8.26705137 < i <= 13.25556757:
    cuartil1.append(3)
  elif i >13.25556757:
    cuartil1.append(4)

# %%
# cuartil para growth 2018
cuartil2 = []
for i in datos['Growth (%)']:
  if i <= -4.26887887:
    cuartil2.append(1)
  elif -4.26887887 < i <= 4.19276684:
    cuartil2.append(2)
  elif 4.19276684 < i <= 15.01946348:
    cuartil2.append(3)
  elif i >15.01946348:
    cuartil2.append(4)

# %%
# cuartil para profitability 2019
cuartil1 = []
for i in datos['Profitability (Return on assets (%))']:
  if i <= 4.15220999:
    cuartil1.append(1)
  elif 4.15220999 < i <= 8.88990631:
    cuartil1.append(2)
  elif 8.88990631 < i <= 13.8373145:
    cuartil1.append(3)
  elif i >13.8373145:
    cuartil1.append(4)

# %%
# cuartil para growth 2019
cuartil2 = []
for i in datos['Growth (%)']:
  if i <= -1.79091953:
    cuartil2.append(1)
  elif -1.79091953 < i <= 6.96613971:
    cuartil2.append(2)
  elif 6.96613971 < i <= 16.774314:
    cuartil2.append(3)
  elif i >16.774314:
    cuartil2.append(4)

# %%
# cuartil para profitability 2020
cuartil1 = []
for i in datos['Profitability (Return on assets (%))']:
  if i <= 2.8744614:
    cuartil1.append(1)
  elif 2.8744614 < i <= 7.88131185:
    cuartil1.append(2)
  elif 7.88131185 < i <= 13.61391813:
    cuartil1.append(3)
  elif i >13.61391813:
    cuartil1.append(4)

# %%
# cuartil para growth 2020
cuartil2 = []
for i in datos['Growth (%)']:
  if i <= -22.7132921:
    cuartil2.append(1)
  elif -22.7132921 < i <= -4.3979689:
    cuartil2.append(2)
  elif -4.3979689 < i <= 10.6679224:
    cuartil2.append(3)
  elif i >10.6679224:
    cuartil2.append(4)

# %%
# cuartil para profitability 2021
cuartil = []
for i in datos['Profitability (Return on assets (%))']:
  if i <= 4.12107333:
    cuartil.append(1)
  elif 4.12107333 < i <= 9.94966159:
    cuartil.append(2)
  elif 9.94966159 < i <= 18.00933112:
    cuartil.append(3)
  elif i >18.00933112:
    cuartil.append(4)

# %%
# cuartil para growth 2021
cuartil = []
for i in datos['Growth (%)']:
  if i <= 9.3188124:
    cuartil.append(1)
  elif 9.3188124 < i <= 26.67722425:
    cuartil.append(2)
  elif 26.67722425 < i <= 48.52069578:
    cuartil.append(3)
  elif i >48.52069578:
    cuartil.append(4)

# %%
datos['profit'] = cuartil1
datos['growth'] = cuartil2

# %%
rango = range(len(datos.index))

# %%
# performance group 2017
grupo = []
for i in rango:
  if datos.loc[i, 'Clasificación Profitability 2017'] == 1 and datos.loc[i, 'Clasificación Growth 2017'] == 1:
    grupo.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 1 and datos.loc[i, 'Clasificación Growth 2017'] == 2:
    grupo.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 2 and datos.loc[i, 'Clasificación Growth 2017'] == 1:
    grupo.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 2 and datos.loc[i, 'Clasificación Growth 2017'] == 2:
    grupo.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 2 and datos.loc[i, 'Clasificación Growth 2017'] == 3:
    grupo.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 3 and datos.loc[i, 'Clasificación Growth 2017'] == 2:
    grupo.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 3 and datos.loc[i, 'Clasificación Growth 2017'] == 3:
    grupo.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 3 and datos.loc[i, 'Clasificación Growth 2017'] == 1:
    grupo.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 4 and datos.loc[i, 'Clasificación Growth 2017'] == 1:
    grupo.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 4 and datos.loc[i, 'Clasificación Growth 2017'] == 2:
    grupo.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 1 and datos.loc[i, 'Clasificación Growth 2017'] == 3:
    grupo.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 1 and datos.loc[i, 'Clasificación Growth 2017'] == 4:
    grupo.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 2 and datos.loc[i, 'Clasificación Growth 2017'] == 4:
    grupo.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 3 and datos.loc[i, 'Clasificación Growth 2017'] == 4:
    grupo.append('Star')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 4 and datos.loc[i, 'Clasificación Growth 2017'] == 3:
    grupo.append('Star')
  elif datos.loc[i, 'Clasificación Profitability 2017'] == 4 and datos.loc[i, 'Clasificación Growth 2017'] == 4:
    grupo.append('Star')

# %%
# performance group 2018
grupo1 = []
for i in rango:
  if datos.loc[i, 'Clasificación Profitability 2018'] == 1 and datos.loc[i, 'Clasificación Growth 2018'] == 1:
    grupo1.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 1 and datos.loc[i, 'Clasificación Growth 2018'] == 2:
    grupo1.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 2 and datos.loc[i, 'Clasificación Growth 2018'] == 1:
    grupo1.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 2 and datos.loc[i, 'Clasificación Growth 2018'] == 2:
    grupo1.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 2 and datos.loc[i, 'Clasificación Growth 2018'] == 3:
    grupo1.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 3 and datos.loc[i, 'Clasificación Growth 2018'] == 2:
    grupo1.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 3 and datos.loc[i, 'Clasificación Growth 2018'] == 3:
    grupo1.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 3 and datos.loc[i, 'Clasificación Growth 2018'] == 1:
    grupo1.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 4 and datos.loc[i, 'Clasificación Growth 2018'] == 1:
    grupo1.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 4 and datos.loc[i, 'Clasificación Growth 2018'] == 2:
    grupo1.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 1 and datos.loc[i, 'Clasificación Growth 2018'] == 3:
    grupo1.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 1 and datos.loc[i, 'Clasificación Growth 2018'] == 4:
    grupo1.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 2 and datos.loc[i, 'Clasificación Growth 2018'] == 4:
    grupo1.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 3 and datos.loc[i, 'Clasificación Growth 2018'] == 4:
    grupo1.append('Star')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 4 and datos.loc[i, 'Clasificación Growth 2018'] == 3:
    grupo1.append('Star')
  elif datos.loc[i, 'Clasificación Profitability 2018'] == 4 and datos.loc[i, 'Clasificación Growth 2018'] == 4:
    grupo1.append('Star')

# %%
# performance group 2019
grupo2 = []
for i in rango:
  if datos.loc[i, 'Clasificación Profitability 2019'] == 1 and datos.loc[i, 'Clasificación Growth 2019'] == 1:
    grupo2.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 1 and datos.loc[i, 'Clasificación Growth 2019'] == 2:
    grupo2.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 2 and datos.loc[i, 'Clasificación Growth 2019'] == 1:
    grupo2.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 2 and datos.loc[i, 'Clasificación Growth 2019'] == 2:
    grupo2.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 2 and datos.loc[i, 'Clasificación Growth 2019'] == 3:
    grupo2.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 3 and datos.loc[i, 'Clasificación Growth 2019'] == 2:
    grupo2.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 3 and datos.loc[i, 'Clasificación Growth 2019'] == 3:
    grupo2.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 3 and datos.loc[i, 'Clasificación Growth 2019'] == 1:
    grupo2.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 4 and datos.loc[i, 'Clasificación Growth 2019'] == 1:
    grupo2.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 4 and datos.loc[i, 'Clasificación Growth 2019'] == 2:
    grupo2.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 1 and datos.loc[i, 'Clasificación Growth 2019'] == 3:
    grupo2.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 1 and datos.loc[i, 'Clasificación Growth 2019'] == 4:
    grupo2.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 2 and datos.loc[i, 'Clasificación Growth 2019'] == 4:
    grupo2.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 3 and datos.loc[i, 'Clasificación Growth 2019'] == 4:
    grupo2.append('Star')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 4 and datos.loc[i, 'Clasificación Growth 2019'] == 3:
    grupo2.append('Star')
  elif datos.loc[i, 'Clasificación Profitability 2019'] == 4 and datos.loc[i, 'Clasificación Growth 2019'] == 4:
    grupo2.append('Star')

# %%
# performance group 2020
grupo3 = []
for i in rango:
  if datos.loc[i, 'Clasificación Profitability 2020'] == 1 and datos.loc[i, 'Clasificación Growth 2020'] == 1:
    grupo3.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 1 and datos.loc[i, 'Clasificación Growth 2020'] == 2:
    grupo3.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 2 and datos.loc[i, 'Clasificación Growth 2020'] == 1:
    grupo3.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 2 and datos.loc[i, 'Clasificación Growth 2020'] == 2:
    grupo3.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 2 and datos.loc[i, 'Clasificación Growth 2020'] == 3:
    grupo3.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 3 and datos.loc[i, 'Clasificación Growth 2020'] == 2:
    grupo3.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 3 and datos.loc[i, 'Clasificación Growth 2020'] == 3:
    grupo3.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 3 and datos.loc[i, 'Clasificación Growth 2020'] == 1:
    grupo3.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 4 and datos.loc[i, 'Clasificación Growth 2020'] == 1:
    grupo3.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 4 and datos.loc[i, 'Clasificación Growth 2020'] == 2:
    grupo3.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 1 and datos.loc[i, 'Clasificación Growth 2020'] == 3:
    grupo3.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 1 and datos.loc[i, 'Clasificación Growth 2020'] == 4:
    grupo3.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 2 and datos.loc[i, 'Clasificación Growth 2020'] == 4:
    grupo3.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 3 and datos.loc[i, 'Clasificación Growth 2020'] == 4:
    grupo3.append('Star')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 4 and datos.loc[i, 'Clasificación Growth 2020'] == 3:
    grupo3.append('Star')
  elif datos.loc[i, 'Clasificación Profitability 2020'] == 4 and datos.loc[i, 'Clasificación Growth 2020'] == 4:
    grupo3.append('Star')

# %%
# performance group 2021
grupo = []
for i in rango:
  if datos.loc[i, 'Clasificación Profitability 2021'] == 1 and datos.loc[i, 'Clasificación Growth 2021'] == 1:
    grupo.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 1 and datos.loc[i, 'Clasificación Growth 2021'] == 2:
    grupo.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 2 and datos.loc[i, 'Clasificación Growth 2021'] == 1:
    grupo.append('Poor')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 2 and datos.loc[i, 'Clasificación Growth 2021'] == 2:
    grupo.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 2 and datos.loc[i, 'Clasificación Growth 2021'] == 3:
    grupo.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 3 and datos.loc[i, 'Clasificación Growth 2021'] == 2:
    grupo.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 3 and datos.loc[i, 'Clasificación Growth 2021'] == 3:
    grupo.append('Middle')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 3 and datos.loc[i, 'Clasificación Growth 2021'] == 1:
    grupo.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 4 and datos.loc[i, 'Clasificación Growth 2021'] == 1:
    grupo.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 4 and datos.loc[i, 'Clasificación Growth 2021'] == 2:
    grupo.append('Profit')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 1 and datos.loc[i, 'Clasificación Growth 2021'] == 3:
    grupo.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 1 and datos.loc[i, 'Clasificación Growth 2021'] == 4:
    grupo.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 2 and datos.loc[i, 'Clasificación Growth 2021'] == 4:
    grupo.append('Growth')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 3 and datos.loc[i, 'Clasificación Growth 2021'] == 4:
    grupo.append('Star')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 4 and datos.loc[i, 'Clasificación Growth 2021'] == 3:
    grupo.append('Star')
  elif datos.loc[i, 'Clasificación Profitability 2021'] == 4 and datos.loc[i, 'Clasificación Growth 2021'] == 4:
    grupo.append('Star')

# %%
datos['2018'] = grupo1
datos['2019'] = grupo2
datos['2020'] = grupo3

# %%
datos.to_excel(r'consolidado 10 y 11 con nuevas variables.xlsx', index=False)
